# %% [markdown]
# Day-27

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\boyal\OneDrive\Desktop\Applied_Agentic_AI\Python\Day_27
# ['.ipynb_checkpoints', 'Day_27.ipynb', 'example.txt']

# %%
# Store the data --> Files (.txt files) --> open()
# Files modes --> 'r','w','a'

file = open("example.txt","r")
print(file)
print(file.read()) # return the entire text from  the file 
print(file.read(10)) # we can also mention size
a = file.readlines()
print(len(a))
print(file.readline())
# Out:
# <_io.TextIOWrapper name='example.txt' mode='r' encoding='cp1252'>
# AAA-HYD_001APPLED AGENTIC AI
#
# 0

# %%
#print(file.readlines())
import os
if os.path.exists('example.txt'):
    f = open('example.txt').read()
    print(f)
    print("File is Found")
else:
    print("File not Found")
# Out:
# AAA-HYD_001APPLED AGENTIC AI
# File is Found

# %%
 # default read mode

file_path = 'example.txt'
if os.path.exists(file_path):
    print(f"File Size is {os.path.getsize(file_path)} Bytes")
    print(f'File path is {os.path.abspath(file_path)}')
else:
    print("File not Found")
# w mode --> 

# Open file in write mode
with open("agents.txt", "w") as a:
    a.write("AAA-HYD_001\n")
    a.write("APPLED AGENTIC AI\n")
    a.writelines(["Rag is concept of Agentic Ai\n"])




b = open('example.txt','w')
print(b)
b.writelines("Rag is concept of Agentic Ai")
b.close()
# Out:
# File Size is 28 Bytes
# File path is C:\Users\boyal\OneDrive\Desktop\Applied_Agentic_AI\Python\Day_27\example.txt
# <_io.TextIOWrapper name='example.txt' mode='w' encoding='cp1252'>

# %%
# if the file already present 'w' mode will overrider the content
with open('example.txt','r+') as file:
    # print(file.read())  # raise an error 
    print(file)
    file.writelines("GenAI is Also part of the AAI")
    #file.seek(0)
    print(file.read())
    



# append 

with open('example.txt','a') as f:
    print(f)
    f.write("\n Pyhton,Agents,Rag.....")
    f.writelines("Hi Everyone")

with open('rag.txt','a') as r:
    print(r)
    r.writelines("Agents,Mcp")

with open('rag.txt','r+') as d:
    print(d.read())
    d.write('\n Claude, Cahtgpt, Copilot')
# Out:
# <_io.TextIOWrapper name='example.txt' mode='r+' encoding='cp1252'>
#
# <_io.TextIOWrapper name='example.txt' mode='a' encoding='cp1252'>
# <_io.TextIOWrapper name='rag.txt' mode='a' encoding='cp1252'>
# Agents,Mcp

# %%
    
import os
d = os.listdir()
print(d)

for file in d:
    if file.endswith('.txt'):
        print(file)
# Out:
# ['.ipynb_checkpoints', 'agents.txt', 'Day_27.ipynb', 'example.txt', 'rag.txt']
# agents.txt
# example.txt
# rag.txt

# %%
# Exception Handling --> Program (try,except,finally)

try:
    a, b = map(int, input("Enter a,b values: ").split(','))

    res = a / b
    print(f"Result is {res}")

except ZeroDivisionError:
    print("Denominator cannot be zero.")

except ValueError:
    print("Please enter only integers separated by a comma.")
finally:
    print("Alway will be Printed")
# Out:
# Enter a,b values:  1,2
# Result is 0.5
# Alway will be Printed

# %%
# exception together 
try:
    a, b = map(int, input("Enter a,b values: ").split(','))

    res = a / b
    print(f"Result is {res}")

except (ZeroDivisionError,ValueError) as e:
  print(f"The error occured {e}")

finally:
        print("Alway will be Printed")
# Out:
# Enter a,b values:  0,1
# Result is 0.0
# Alway will be Printed
