# %% [markdown]
# Day-1

# %%
# Variables and Data Types

name = "Jagadeesh"
age = 22
course = "Agentic AI"

print(name)
print(age)
print(course)

print(type(name))
print(type(age))
print(type(course))
