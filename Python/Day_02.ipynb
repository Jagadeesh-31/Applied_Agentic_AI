# %% [markdown]
# Day-2

# %%
# Data Types & Type Conversion

age = 22

print(float(age))
print(complex(age))
print(bool(age))

price = 45.67

print(int(price))
print(str(price))

flag = True

print(int(flag))
print(float(flag))
# Out:
# 22.0
# (22+0j)
# True
# 45
# 45.67
# 1
# 1.0
